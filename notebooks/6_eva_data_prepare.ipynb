# %% [markdown]
# #### Validation for lake level derived by SWOT data.
# 1. lake levels of SWOT pixc data, SWOT LakeSp data, ICESat-2 ATL13 data and DAHITI data.
# 2. Lake levels by using simple average and area-weighted average method.

# %%
import numpy as np
import xarray as xr  
import pandas as pd  
import seaborn as sns 
import matplotlib.pyplot as plt   
from utils.date_transform import decimal_to_date

# %% [markdown]
# ### 1. swot pixc vs. swot lakesp vs. dahiti

# %%
## dianchi
path_DAHITI_dianchi= 'data/dahiti/Dan Chi.nc'  
path_pixc_wse_dianchi = 'data/swot_l2/pixc/dianchi-lake/dianchi_pixc_wse.csv'  
path_lakesp_wse_dianchi = 'data/swot_l2/lakesp/dianchi-lake/dianchi_wse_lakesp.csv'

## erhai
path_DAHITI_erhai = 'data/dahiti/ErHai.nc'
path_pixc_wse_erhai = 'data/swot_l2/pixc/erhai-lake/erhai_pixc_wse.csv'
path_lakesp_wse_erhai = 'data/swot_l2/lakesp/erhai-lake/erhai_wse_lakesp.csv'

# %% [markdown]
# #### 1.1 DAHITI水位数据处理（转换基准为EGM2008）

# %%
def read2month_nc(path_dahiti, date_var='datetime', wse_var='water_level'):
  '''
  (1) read dahiti data and convert to dataframe
  (2) convert date to monthly date
  (3) convert elevation reference of eigen-6c4 to egm2008
  '''
  dahiti_xr = xr.open_dataset(path_dahiti)
  dahiti_df = dahiti_xr.to_dataframe()
  dahiti_df[date_var] = pd.to_datetime(dahiti_df[date_var])
  dahiti_df['year_month'] = dahiti_df[date_var].dt.to_period('M') 
  dahiti_wse_month = dahiti_df.groupby('year_month')[wse_var].median().reset_index()
  dahiti_wse_month = dahiti_wse_month.rename(columns={wse_var: 'dahiti_wse'})
  dahiti_wse_month = dahiti_wse_month.set_index('year_month')
  # 基准由DAHITI的EIGEN-6C4转为wgs84,再转为EGM2008
  dahiti_wse_month['dahiti_wse'] = dahiti_wse_month['dahiti_wse'] + (-32.2242)-(-32.1375)
  return dahiti_wse_month

dahiti_wse_month_dianchi = read2month_nc(path_DAHITI_dianchi)
dahiti_wse_month_erhai = read2month_nc(path_DAHITI_erhai)
dahiti_wse_month_erhai
# Out:
#              dahiti_wse
# year_month
# 2016-05     1965.288208
# 2016-06     1965.083252
# 2016-07     1965.069214
# 2016-08     1965.178711
# 2016-09     1965.405151
# ...                 ...
# 2024-08     1965.119263
# 2024-09     1965.403198
# 2024-10     1965.537231
# 2024-11     1965.607178
# 2024-12     1965.392212
#
# [97 rows x 1 columns]

# %% [markdown]
# #### 1.2 基于SWOT Pixc数据的水位信息

# %%
def read2month_csv(path_lake_wse, var_name='lake_wse'):
    '''    
    (1) read pixc/lakesp/icesat2 data and convert to dataframe
    (2) convert decimal date to monthly date
    '''
    lake_wse = pd.read_csv(path_lake_wse)
    lake_wse['date'] = lake_wse['date'].apply(decimal_to_date)  
    lake_wse['date'] = pd.to_datetime(lake_wse['date'])  # 转换为datetime格式
    lake_wse['year_month'] = lake_wse['date'].dt.to_period('M') 
    lake_wse_month = lake_wse.groupby('year_month')[var_name].median().reset_index()    
    lake_wse_month = lake_wse_month.set_index('year_month')     
    return lake_wse_month

# %%
pixc_wse_month_dianchi = read2month_csv(path_pixc_wse_dianchi, var_name='height_weighted_mean')
pixc_wse_month_dianchi = pixc_wse_month_dianchi.rename(columns={'height_weighted_mean': 'swot_pixc_wse'})
pixc_wse_month_erhai = read2month_csv(path_pixc_wse_erhai, var_name='height_weighted_mean')
pixc_wse_month_erhai = pixc_wse_month_erhai.rename(columns={'height_weighted_mean': 'swot_pixc_wse'})
pixc_wse_month_dianchi
# Out:
#             swot_pixc_wse
# year_month
# 2023-09        1887.75990
# 2023-10        1887.77140
# 2023-11        1887.76320
# 2023-12        1887.76390
# 2024-01        1887.70860
# 2024-02        1887.73400
# 2024-03        1887.69600
# 2024-04        1887.64030
# 2024-06        1887.59665
# 2024-07        1887.59920
# 2024-08        1887.70130
# 2024-09        1887.76215
# 2024-11        1887.76715
# 2024-12        1887.78600

# %% [markdown]
# #### 1.3 基于LakeSP数据的SWOT水位信息

# %%
lakesp_wse_month_dianchi = read2month_csv(path_lakesp_wse_dianchi, var_name='swot_lakesp_wse')
lakesp_wse_month_erhai = read2month_csv(path_lakesp_wse_erhai, var_name='swot_lakesp_wse')
lakesp_wse_month_dianchi.head()
# Out:
#             swot_lakesp_wse
# year_month
# 2023-08           1888.0170
# 2023-09           1887.8810
# 2023-10           1887.9540
# 2023-11           1887.8230
# 2023-12           1887.8535

# %% [markdown]
# #### 1.4 数据合并及对比分析
# 合并数据--均方根计算--可视化

# %%
dahiti_wse_month = dahiti_wse_month_dianchi
pixc_wse_month = pixc_wse_month_dianchi.rename(columns={'height_weighted_mean': 'swot_pixc_wse'})
lakesp_wse_month = lakesp_wse_month_dianchi

## 合并三个水位产品
dahiti_pixc_lakesp_df = pixc_wse_month.merge(dahiti_wse_month, on='year_month', how='left').\
                                                            merge(lakesp_wse_month, on='year_month', how='left')
dahiti_pixc_lakesp_df = dahiti_pixc_lakesp_df.interpolate(method='linear', limit_area='inside') 
dahiti_pixc_lakesp_df = dahiti_pixc_lakesp_df.reindex(columns=['dahiti_wse', 'swot_pixc_wse', 'swot_lakesp_wse'])

#计算均方根误差和相关性
dif_dahiti_lakesp = dahiti_pixc_lakesp_df['swot_lakesp_wse'] - dahiti_pixc_lakesp_df['dahiti_wse']
dif_dahiti_pixc = dahiti_pixc_lakesp_df['swot_pixc_wse'] - dahiti_pixc_lakesp_df['dahiti_wse']

### 计算均方根误差
## 计算差值的均值(系统偏差，以dahiti为参考)
mean_dif_dahiti_lakesp = dif_dahiti_lakesp.mean()
mean_dif_dahiti_pixc = dif_dahiti_pixc.mean()

# 将均值加到wse_month列（以DAHITI为参考, 消除系统偏差）
dahiti_pixc_lakesp_df['swot_pixc_wse_cor'] = dahiti_pixc_lakesp_df['swot_pixc_wse'] - mean_dif_dahiti_pixc
dahiti_pixc_lakesp_df['swot_lakesp_wse_cor'] = dahiti_pixc_lakesp_df['swot_lakesp_wse'] - mean_dif_dahiti_lakesp 
dahiti_pixc_lakesp_df
# Out:
#              dahiti_wse  swot_pixc_wse  swot_lakesp_wse  swot_pixc_wse_cor  \
# year_month
# 2023-09     1887.431152     1887.75990        1887.8810        1887.495325
# 2023-10     1887.530151     1887.77140        1887.9540        1887.506825
# 2023-11     1887.597168     1887.76320        1887.8230        1887.498625
# 2023-12     1887.448242     1887.76390        1887.8535        1887.499325
# 2024-01     1887.426147     1887.70860        1888.0540        1887.444025
# 2024-02     1887.460205     1887.73400        1887.9395        1887.469425
# 2024-03     1887.459229     1887.69600        1887.8000        1887.431425
# 2024-04     1887.319214     1887.64030        1887.7810        1887.375725
# 2024-06     1887.294189     1887.59665        1887.7540        1887.332075
# 2024-07     1887.264160     1887.59920        1887.7270        1887.334625
# 2024-08     1887.464233     1887.70130        1887.8720        1887.436725
# ...

# %%
## merge_dahiti_pixc_lakesp
def merge_dahiti_pixc_lakesp(dahiti_wse_month, pixc_wse_month, lakesp_wse_month):
    '''
    (1) merge dahiti, pixc, lakesp, isat2 data into one dataframe
    (2) interpolate missing values
    (3) system bias correction for pixc and lakesp data by use dahiti data as reference
    '''
    ## 合并三个水位产品
    dahiti_pixc_lakesp_df = pixc_wse_month.merge(dahiti_wse_month, on='year_month', how='left').\
                                                merge(lakesp_wse_month, on='year_month', how='left')
    dahiti_pixc_lakesp_df = dahiti_pixc_lakesp_df.interpolate(method='linear', limit_area='inside') 
    dahiti_pixc_lakesp_df = dahiti_pixc_lakesp_df.reindex(columns=['dahiti_wse', 'swot_pixc_wse', 'swot_lakesp_wse'])

    #计算均方根误差和相关性
    dif_dahiti_lakesp = dahiti_pixc_lakesp_df['swot_lakesp_wse'] - dahiti_pixc_lakesp_df['dahiti_wse']
    dif_dahiti_pix = dahiti_pixc_lakesp_df['swot_pixc_wse'] - dahiti_pixc_lakesp_df['dahiti_wse']
    ## 计算均方根误差
    ## 计算差值的均值(系统偏差，以dahiti为参考)
    mean_dif_dahiti_lakesp = dif_dahiti_lakesp.mean()
    mean_dif_dahiti_pix = dif_dahiti_pix.mean()

    # 将均值加到wse_month列（以DAHITI为参考, 消除系统偏差）
    dahiti_pixc_lakesp_df['swot_pixc_wse_cor'] = dahiti_pixc_lakesp_df['swot_pixc_wse'] - mean_dif_dahiti_pix
    dahiti_pixc_lakesp_df['swot_lakesp_wse_cor'] = dahiti_pixc_lakesp_df['swot_lakesp_wse'] - mean_dif_dahiti_lakesp
    ### write out
    return dahiti_pixc_lakesp_df

dahiti_pixc_lakesp_dianchi = merge_dahiti_pixc_lakesp(dahiti_wse_month_dianchi, \
                                                            pixc_wse_month_dianchi, lakesp_wse_month_dianchi)
dahiti_pixc_lakesp_erhai = merge_dahiti_pixc_lakesp(dahiti_wse_month_erhai, pixc_wse_month_erhai, \
                                                            lakesp_wse_month_erhai)
dahiti_pixc_lakesp_dianchi

# # ## save to csv
# path_dahiti_pixc_lakesp_dianchi = 'data/eva-data/dahiti_pixc_lakesp_dianchi.csv' ## save to path
# path_dahiti_pixc_lakesp_erhai = 'data/eva-data/dahiti_pixc_lakesp_erhai.csv' ## save to path
# dahiti_pixc_lakesp_dianchi.to_csv(path_dahiti_pixc_lakesp_dianchi, index=True)
# dahiti_pixc_lakesp_erhai.to_csv(path_dahiti_pixc_lakesp_erhai, index=True)
# Out:
#              dahiti_wse  swot_pixc_wse  swot_lakesp_wse  swot_pixc_wse_cor  \
# year_month
# 2023-09     1887.431152     1887.75990        1887.8810        1887.495325
# 2023-10     1887.530151     1887.77140        1887.9540        1887.506825
# 2023-11     1887.597168     1887.76320        1887.8230        1887.498625
# 2023-12     1887.448242     1887.76390        1887.8535        1887.499325
# 2024-01     1887.426147     1887.70860        1888.0540        1887.444025
# 2024-02     1887.460205     1887.73400        1887.9395        1887.469425
# 2024-03     1887.459229     1887.69600        1887.8000        1887.431425
# 2024-04     1887.319214     1887.64030        1887.7810        1887.375725
# 2024-06     1887.294189     1887.59665        1887.7540        1887.332075
# 2024-07     1887.264160     1887.59920        1887.7270        1887.334625
# 2024-08     1887.464233     1887.70130        1887.8720        1887.436725
# ...

# %%
## accuracy
## dianchi 
dif_pix_dahiti = dahiti_pixc_lakesp_dianchi['dahiti_wse']-dahiti_pixc_lakesp_dianchi['swot_pixc_wse_cor']
dif_lakesp_dahiti = dahiti_pixc_lakesp_dianchi['dahiti_wse']-dahiti_pixc_lakesp_dianchi['swot_lakesp_wse_cor']
print('dianchi(pixc):', dif_pix_dahiti.std(), 'dianchi(lakesp):', dif_lakesp_dahiti.std())
## erhai 
dif_pix_dahiti = dahiti_pixc_lakesp_erhai['dahiti_wse']-dahiti_pixc_lakesp_erhai['swot_pixc_wse_cor']
dif_lakesp_dahiti = dahiti_pixc_lakesp_erhai['dahiti_wse']-dahiti_pixc_lakesp_erhai['swot_lakesp_wse_cor']
print('erhai(pixc):', dif_pix_dahiti.std(), 'erhai(lakesp):', dif_lakesp_dahiti.std())
# Out:
# dianchi(pixc): 0.05653751261582528 dianchi(lakesp): 0.09420436028389548
# erhai(pixc): 0.08969790578445476 erhai(lakesp): 0.12934579386896344

# %%
import matplotlib.ticker as ticker 
from matplotlib import dates as mdates
from matplotlib.ticker import MultipleLocator

df = dahiti_pixc_lakesp_erhai.copy()
df['year_month'] = df.index.to_timestamp()
fig, ax = plt.subplots(figsize=(6, 3))
sns.lineplot(data=df, x='year_month', y='dahiti_wse', label='DAHITI WSE', ax=ax, color='orange')
sns.lineplot(data=df, x='year_month', y='swot_pixc_wse', label='SWOT WSE', color='blue', ax=ax)
sns.lineplot(data=df, x='year_month', y='swot_pixc_wse_cor', label='Corrected SWOT WSE', ax=ax, color='green')
sns.scatterplot(data=df, x='year_month', y='dahiti_wse', ax=ax, color='orange', s=50)
sns.scatterplot(data=df, x='year_month', y='swot_pixc_wse',  ax=ax, color='blue', s=50)
sns.scatterplot(data=df, x='year_month', y='swot_pixc_wse_cor',  ax=ax, color='green', s=50)

## 固定刻度位置和标签
specific_months = ['2023-09', '2024-01', '2024-05', '2024-09']
# specific_dates = [pd.to_datetime(month + '-01') for month in specific_months]
specific_dates = pd.to_datetime(specific_months)
y_step = 0.5
ax.legend(fontsize=9)
ax.set_xticks(specific_dates)
ax.set_xticklabels(specific_months)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:.1f}'))
ax.yaxis.set_major_locator(MultipleLocator(y_step)) 
# ax.set_ylim(1887.1, 1888.1)  ## dianchi   
ax.set_ylim(1964.6, 1966.4)   ## erhai
# Out:
# (1964.6, 1966.4)

# %% [markdown]
# ### 2. merge isat-2 wse and pix wse.

# %%
path_isat2_wse_dianchi = 'data/isat2/dianchi/dianchi_wse_isat2.csv'     
path_isat2_wse_erhai = 'data/isat2/erhai/erhai_wse_isat2.csv'

# %%
isat2_wse_month_dianchi = read2month_csv(path_isat2_wse_dianchi, var_name='isat2_wse')
isat2_wse_month_erhai = read2month_csv(path_isat2_wse_erhai, var_name='isat2_wse')
isat2_wse_month_erhai
# Out:
#               isat2_wse
# year_month
# 2023-01     1965.729320
# 2023-02     1965.577486
# 2023-04     1965.232883
# 2023-05     1964.991120
# 2023-10     1966.339610
# 2023-11     1966.231429
# 2024-01     1966.048499
# 2024-04     1965.571459
# 2024-05     1965.382685
# 2024-07     1965.390286
# 2024-08     1965.441863
# 2024-11     1965.975530

# %%
## merge_pixc_isat2
def merge_pixc_isat2(pixc_wse_month, isat2_wse_month):
    '''
    (1) merge pixc, isat2 data into one dataframe
    (2) system bias correction for pixc data by use isat2 data as reference
    '''
    ## merge lake heights from different sources
    pixc_isat2_df = pixc_wse_month.merge(isat2_wse_month, on='year_month', how='left')
    # pixc_isat2_df = pixc_isat2_df.interpolate(method='linear', limit_area='inside')
    pixc_isat2_df = pixc_isat2_df.reindex(columns=['swot_pixc_wse', 'isat2_wse'])
    #计算均方根误差和相关性
    dif_pixc_isat2 = pixc_isat2_df['isat2_wse'] - pixc_isat2_df['swot_pixc_wse']
    ## 计算均方根误差
    ## 计算差值的均值(系统偏差，以swot pixc为参考)
    mean_dif_pixc_isat2 = dif_pixc_isat2.mean()
    pixc_isat2_df['isat2_wse_cor'] = pixc_isat2_df['isat2_wse'] - mean_dif_pixc_isat2
    ### write out
    return pixc_isat2_df

pixc_isat2_dianchi = merge_pixc_isat2(pixc_wse_month_dianchi, isat2_wse_month_dianchi)
pixc_isat2_erhai = merge_pixc_isat2(pixc_wse_month_erhai, isat2_wse_month_erhai)
pixc_isat2_dianchi
# # ## save to csv
# path_pixc_isat2_dianchi = 'data/eva-data/pixc_isat2_dianchi.csv' ## save to path
# path_pixc_isat2_erhai = 'data/eva-data/pixc_isat2_erhai.csv' ## save to path
# pixc_isat2_dianchi.to_csv(path_pixc_isat2_dianchi, index=True)
# pixc_isat2_erhai.to_csv(path_pixc_isat2_erhai, index=True)
# Out:
#             swot_pixc_wse    isat2_wse  isat2_wse_cor
# year_month
# 2023-09        1887.75990          NaN            NaN
# 2023-10        1887.77140  1887.784377    1887.768678
# 2023-11        1887.76320          NaN            NaN
# 2023-12        1887.76390          NaN            NaN
# 2024-01        1887.70860          NaN            NaN
# 2024-02        1887.73400          NaN            NaN
# 2024-03        1887.69600          NaN            NaN
# 2024-04        1887.64030          NaN            NaN
# 2024-06        1887.59665          NaN            NaN
# 2024-07        1887.59920  1887.550864    1887.535166
# 2024-08        1887.70130          NaN            NaN
# 2024-09        1887.76215          NaN            NaN
# 2024-11        1887.76715  1887.849604    1887.833906
# 2024-12        1887.78600          NaN            NaN

# %% [markdown]
# ### 3. 像素云面积加权平均 vs 普通平均

# %%
## dianchi
# path_unweighted_dianchi = 'data/swot_l2/pixc/dianchi-lake/dianchi_heights_simple_mean.pkl'  
path_swot_pixc_wse_dianchi = 'data/swot_l2/pixc/dianchi-lake/dianchi_pixc_wse.csv'
path_dahiti_pixc_lakesp_dianchi = 'data/eva-data/dahiti_pixc_lakesp_dianchi.csv' ## 
## erhai
# path_unweighted_erhai = 'data/swot_l2/pixc/erhai-lake/erhai_heights_simple_mean.pkl'
path_swot_pixc_wse_erhai = 'data/swot_l2/pixc/erhai-lake/erhai_pixc_wse.csv'
path_dahiti_pixc_lakesp_erhai = 'data/eva-data/dahiti_pixc_lakesp_erhai.csv' ##

# %% [markdown]
# ##### 2.1 所提方法获得结果（SWOT_pixc_wse, SWOT_pixc_wse_cor）

# %%
dahiti_pixc_lakesp_dianchi = pd.read_csv(path_dahiti_pixc_lakesp_dianchi, index_col=0)
dahiti_pixc_lakesp_erhai = pd.read_csv(path_dahiti_pixc_lakesp_erhai, index_col=0)
dahiti_pixc_lakesp_erhai
# Out:
#             dahiti_wse  swot_pixc_wse  swot_lakesp_wse  swot_pixc_wse_cor  \
# year_month
# 2023-09      1965.4342     1965.96600              NaN        1965.418838
# 2023-11      1965.5702     1966.27185      1966.447667        1965.724688
# 2023-12      1965.6812     1966.13730      1966.378500        1965.590138
# 2024-01      1965.5062     1966.03260      1966.353333        1965.485438
# 2024-02      1965.4037     1966.02760      1966.234000        1965.480438
# 2024-03      1965.3011     1965.79340      1965.936000        1965.246238
# 2024-04      1965.0922     1965.59310      1965.780000        1965.045938
# 2024-05      1964.8522     1965.44570      1965.599000        1964.898538
# 2024-06      1964.8743     1965.36180      1965.743000        1964.814638
# 2024-07      1964.8757     1965.37000      1965.557000        1964.822838
# 2024-08      1965.1193     1965.76500      1965.931000        1965.217838
# ...

# %% [markdown]
# ##### 2.2 普通平均方法（非加权）所得结果

# %%
dianchi_pixc_wse = pd.read_csv(path_swot_pixc_wse_dianchi)
dianchi_pixc_wse = dianchi_pixc_wse.loc[:, ['date', 'height_mean', 'height_weighted_mean']]  
dianchi_pixc_wse = dianchi_pixc_wse.rename(columns={'height_mean': 'pixc_wse_unweighted', 'height_weighted_mean': 'pixc_wse_weighted'})

erhai_pixc_wse = pd.read_csv(path_swot_pixc_wse_erhai)
erhai_pixc_wse = erhai_pixc_wse.loc[:, ['date', 'height_mean', 'height_weighted_mean']]  
erhai_pixc_wse = erhai_pixc_wse.rename(columns={'height_mean': 'pixc_wse_unweighted', 'height_weighted_mean': 'pixc_wse_weighted'})
erhai_pixc_wse.head()
# Out:
#         date  pixc_wse_unweighted  pixc_wse_weighted
# 0  2023.6731          1965.965946          1965.9660
# 1  2023.8446          1966.310576          1966.3104
# 2  2023.9018          1966.233126          1966.2333
# 3  2023.9590          1966.137322          1966.1373
# 4  2024.0161          1965.997812          1965.9985

# %%
def date_convert(data_df):
    data_df_ = data_df.copy()
    data_df_['date'] = data_df_['date'].apply(decimal_to_date)  
    data_df_['year_month'] = pd.to_datetime(data_df_['date']).dt.to_period('M').astype(str)  # 转换为字符串格式 
    # simple average level
    numeric_cols = data_df_.select_dtypes(include='number').columns
    data_month_df = data_df_.groupby('year_month')[numeric_cols].mean().reset_index()
    data_month_df = data_month_df.set_index('year_month')
    return data_month_df

dianchi_pixc_wse_month = date_convert(dianchi_pixc_wse)
erhai_pixc_wse_month = date_convert(erhai_pixc_wse)
dianchi_pixc_wse_month.head(10)
# Out:
#             pixc_wse_unweighted  pixc_wse_weighted
# year_month
# 2023-09             1887.768024        1887.759900
# 2023-10             1887.776701        1887.771400
# 2023-11             1887.758627        1887.756167
# 2023-12             1887.768764        1887.763900
# 2024-01             1887.694422        1887.699367
# 2024-02             1887.741659        1887.734000
# 2024-03             1887.719592        1887.715167
# 2024-04             1887.645271        1887.640300
# 2024-06             1887.601671        1887.596650
# 2024-07             1887.610290        1887.601233

# %% [markdown]
# ##### 2.3 数据合并及处理

# %%
def merge_bias_correct(dahiti_pixc_lakesp_df, pixc_unweighted_df):
    '''
    (1) merge dahiti_pixc_lakesp_df and pixc_unweight_df into one dataframe
    (2) calculate weighted and unweighted water level
    '''
    # 提取加权水位
    pixc_weighted_df = dahiti_pixc_lakesp_df[['dahiti_wse', 'swot_pixc_wse', 'swot_pixc_wse_cor']]
    pixc_weighted_df = pixc_weighted_df.rename(columns={'swot_pixc_wse': 'pixc_wse_weighted', 
                                                            'swot_pixc_wse_cor': 'pixc_wse_weighted_cor'})
    # 合并加权和非加权数据
    pixc_weighted_unweighted_df = pixc_weighted_df.merge(pixc_unweighted_df, how='outer', on='year_month')
    ## interpolate missing values
    pixc_weighted_unweighted_df = pixc_weighted_unweighted_df.interpolate(method='linear', limit_area='inside')  
    # 非加权方法系统偏差改正（以dahiti为参考）
    dif_unweighted_dahiti = pixc_weighted_unweighted_df['pixc_wse_unweighted'] - pixc_weighted_unweighted_df['dahiti_wse']
    pixc_weighted_unweighted_df['pixc_wse_unweighted_cor'] = pixc_weighted_unweighted_df['pixc_wse_unweighted'] - dif_unweighted_dahiti.mean()
    return pixc_weighted_unweighted_df

# %%
dianchi_dahiti = dahiti_pixc_lakesp_dianchi.loc[:, ['dahiti_wse']]
erhai_dahiti = dahiti_pixc_lakesp_erhai.loc[:, ['dahiti_wse']]

# %%
## 合并加权和非加权数据 
dianchi_dahiti_weighted_unweighted = dianchi_dahiti.merge(dianchi_pixc_wse_month, how='outer', on='year_month')
erhai_dahiti_weighted_unweighted = erhai_dahiti.merge(erhai_pixc_wse_month, how='outer', on='year_month')
# ## 非加权方法系统偏差改正（以dahiti为参考） 
## dianchi  
dianchi_dif_unweighted_dahiti = dianchi_pixc_wse_month['pixc_wse_unweighted'] - dianchi_dahiti['dahiti_wse']
dianchi_dif_weighted_dahiti = dianchi_pixc_wse_month['pixc_wse_weighted'] - dianchi_dahiti['dahiti_wse']
dianchi_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'] = dianchi_dahiti_weighted_unweighted['pixc_wse_unweighted'] - dianchi_dif_unweighted_dahiti.mean()
dianchi_dahiti_weighted_unweighted['pixc_wse_weighted_cor'] = dianchi_dahiti_weighted_unweighted['pixc_wse_weighted'] - dianchi_dif_weighted_dahiti.mean()
## erhai  
erhai_dif_unweighted_dahiti = erhai_dahiti_weighted_unweighted['pixc_wse_unweighted'] - erhai_dahiti['dahiti_wse']
erhai_dif_weighted_dahiti = erhai_dahiti_weighted_unweighted['pixc_wse_weighted'] - erhai_dahiti['dahiti_wse']
erhai_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'] = erhai_dahiti_weighted_unweighted['pixc_wse_unweighted'] - erhai_dif_unweighted_dahiti.mean()
erhai_dahiti_weighted_unweighted['pixc_wse_weighted_cor'] = erhai_dahiti_weighted_unweighted['pixc_wse_weighted'] - erhai_dif_weighted_dahiti.mean()
dianchi_dahiti_weighted_unweighted
# Out:
#             dahiti_wse  pixc_wse_unweighted  pixc_wse_weighted  \
# year_month
# 2023-08      1887.4993                  NaN                NaN
# 2023-09      1887.4312          1887.768024        1887.759900
# 2023-10      1887.5302          1887.776701        1887.771400
# 2023-11      1887.5972          1887.758627        1887.756167
# 2023-12      1887.4482          1887.768764        1887.763900
# 2024-01      1887.4261          1887.694422        1887.699367
# 2024-02      1887.4602          1887.741659        1887.734000
# 2024-03      1887.4592          1887.719592        1887.715167
# 2024-04      1887.3192          1887.645271        1887.640300
# 2024-05      1887.1742                  NaN                NaN
# 2024-06      1887.2942          1887.601671        1887.596650
# 2024-07      1887.2642          1887.610290        1887.601233
# 2024-08      1887.4642          1887.698628        1887.694967
# 2024-09      1887.4712          1887.765063        1887.762150
# ...

# %%
# dahiti_weighted_unweighted_dianchi = merge_dahiti_weighted_unweighted(dianchi_dahiti, dianchi_pixc_wse_month)
# dahiti_weighted_unweighted_erhai = merge_dahiti_weighted_unweighted(erhai_dahiti, erhai_pixc_wse_month)
# dahiti_weighted_unweighted_dianchi

# %%
## accuracy(RMSE, corrected vs not corrected)   
## dianchi   
dianchi_error_corrected_dahiti = (dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])**2
dianchi_error_uncorrected_dahiti = (dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted'])**2
print('dianchi:', np.sqrt(np.nanmean(dianchi_error_corrected_dahiti)), np.sqrt(np.nanmean(dianchi_error_uncorrected_dahiti)))
## erhai    
erhai_error_corrected_dahiti = (erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])**2
erhai_error_uncorrected_dahiti = (erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted'])**2
print('erhai:', np.sqrt(np.nanmean(erhai_error_corrected_dahiti)), np.sqrt(np.nanmean(erhai_error_uncorrected_dahiti)))
# Out:
# dianchi: 0.05440478192401022 0.27056086026469683
# erhai: 0.08551551717487034 0.5593618395099992

# %%
# ## accuracy(MAE,corrected vs not corrected)   
# ## dianchi   
# dianchi_error_corrected_dahiti = abs(dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])
# dianchi_error_uncorrected_dahiti = abs(dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted'])
# print('dianchi:', np.nanmean(dianchi_error_corrected_dahiti), np.nanmean(dianchi_error_uncorrected_dahiti))
# ## erhai    
# erhai_error_corrected_dahiti = abs(erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])
# erhai_error_uncorrected_dahiti = abs(erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted'])
# print('erhai:', np.nanmean(erhai_error_corrected_dahiti), np.nanmean(erhai_error_uncorrected_dahiti))
# Out:
# dianchi: 0.04610340136049932 0.2650345238095854
# erhai: 0.07321900826445926 0.5527863636363732

# %%
## accuracy(RSME, weighted vs unweighted)   
## dianchi   
dianchi_error_weighted_dahiti = (dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])**2
dianchi_error_unweighted_dahiti = (dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'])**2
print('dianchi:', np.sqrt(np.nanmean(dianchi_error_weighted_dahiti)), np.sqrt(np.nanmean(dianchi_error_unweighted_dahiti)))
## erhai    
erhai_error_weighted_dahiti = (erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])**2
erhai_error_unweighted_dahiti = (erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'])**2
print('erhai:', np.sqrt(np.nanmean(erhai_error_weighted_dahiti)), np.sqrt(np.nanmean(erhai_error_unweighted_dahiti)))
# Out:
# dianchi: 0.05440478192401022 0.05541001634814248
# erhai: 0.08551551717487034 0.08570671251019621

# %%
# ## accuracy(MAE, weighted vs unweighted)   
# ## dianchi   
# dianchi_error_weighted_dahiti = abs(dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])
# dianchi_error_unweighted_dahiti = abs(dianchi_dahiti_weighted_unweighted['dahiti_wse'] - dianchi_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'])
# print('dianchi:', np.nanmean(dianchi_error_weighted_dahiti), np.nanmean(dianchi_error_unweighted_dahiti))
# ## erhai    
# erhai_error_weighted_dahiti = abs(erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_weighted_cor'])
# erhai_error_unweighted_dahiti = abs(erhai_dahiti_weighted_unweighted['dahiti_wse'] - erhai_dahiti_weighted_unweighted['pixc_wse_unweighted_cor'])
# print('erhai:', np.nanmean(erhai_error_weighted_dahiti), np.nanmean(erhai_error_unweighted_dahiti))
# Out:
# dianchi: 0.04610340136049932 0.046488469057797896
# erhai: 0.07321900826445926 0.07353167115248156

# %%
# ### save to csv file. 
# path_dahiti_unweighted_weighted_dianchi = 'data/eva-data/dahiti_unweighted_weighted_dianchi.csv' ## save to path
# path_dahiti_unweighted_weighted_erhai = 'data/eva-data/dahiti_unweighted_weighted_erhai.csv' ## save to path
# dianchi_dahiti_weighted_unweighted.to_csv(path_dahiti_unweighted_weighted_dianchi, index=True)
# erhai_dahiti_weighted_unweighted.to_csv(path_dahiti_unweighted_weighted_erhai, index=True)
